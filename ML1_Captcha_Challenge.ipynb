# %% [markdown]
# <a href="https://colab.research.google.com/github/masch78/global_opt/blob/maren/ML1_Captcha_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning 1 - KIT
#
# In this exercise you will classify images taken from google's reCAPTCHA.
# <div>
# <img src=https://i.ds.at/LuvqbQ/rs:fill:1600:0/plain/2022/06/23/captcha.jpg width="300">
# <div>
#
# reCAPTCHA was created to differentiate between real humans and computer porgrams. With the breakthrough of deep learning based methods, these tactics to differentiate between humans and machines no longer work. Computer programs nowadays are perfectly able to solve classic captchas.
#
# This notebook shows the initial steps to load the datasets, create a dummy classifier and use the classifier to create the resulting file, which you will upload for grading.

# %% [markdown]
# ## Your Task
#
#
#
# *   Split the labeled Data into sensible training and validation datasets
# *   Train a model to classify the training data
# *   Evaluate the model on your validation data
# *   If you think your model has a high accuracy, and is generalized well, predict the classes of the images from the testdataset and upload the results.csv at https://kit-ml1.streamlitapp.com/
# * You will get Bonus Points in the exam if your accuracy on test-data is high enough
#
# ## Learning Goals
#
# * How to preprocess data
# * How to split data to prevent over- and underfitting
# * How to train a model
# * How to improve accuracy on unlabeled data
#     * Model architecture
#     * Model initialization
#     * Optimizer
#     * Batch size
#     * Image Augmentation
#     * ...

# %%
## Lots of imports
import matplotlib.pyplot as plt # for visualization
import numpy as np #for fast calculation of matrices and vectors
import os # for reading and writing files
import pandas as pd # for creating dataframes and later saving the .csv
import torch # PyTorch
import torch.nn as nn # layers of neural netowrk
from torch.utils.data import random_split, DataLoader # Creating datasets
import torchvision # the part of PyTorch which is used for images
from torchvision import datasets, models, transforms # used for loading images


torch.manual_seed(3407) # makes your code deterministic so you can compare your results
np.random.seed(3407)

# %% [markdown]
# Download the two .zip files that are available on ilias.
# You should have `train_val.zip` and `test.zip`

# %% [markdown]
# ## Using Google Colab and Google Drive
#
#
# * Upload both files (drag and drop) to your free google drive account https://drive.google.com/drive/my-drive
# * On the left press the folder (Dateien) Symbol.
# * Then press the *Mount drive/ Drive bereitstellen* button which has the google drive symbol (triangle)
# * Allow access to your google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## If you did this correctly you should see here "drive" and "sample_data"
from google.colab import drive
drive.mount('/content/drive')
# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# drive  sample_data

# %% [markdown]
# Unzip the files in your Google Drive
# Only once

# %%
#!unzip drive/MyDrive/train_val.zip -d drive/MyDrive/
#!unzip drive/MyDrive/test.zip -d drive/MyDrive/
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   inflating: drive/MyDrive/test_data/test/06730.png
#   inflating: drive/MyDrive/test_data/test/06731.png
#   inflating: drive/MyDrive/test_data/test/06732.png
#   inflating: drive/MyDrive/test_data/test/06733.png
#   inflating: drive/MyDrive/test_data/test/06734.png
#   inflating: drive/MyDrive/test_data/test/06735.png
#   inflating: drive/MyDrive/test_data/test/06736.png
#   inflating: drive/MyDrive/test_data/test/06737.png
#   inflating: drive/MyDrive/test_data/test/06738.png
#   inflating: drive/MyDrive/test_data/test/06739.png
#   inflating: drive/MyDrive/test_data/test/06740.png
#   inflating: drive/MyDrive/test_data/test/06741.png
#  extracting: drive/MyDrive/test_data/test/06742.png
#   inflating: drive/MyDrive/test_data/test/06743.png
#   inflating: drive/MyDrive/test_data/test/06744.png
#   inflating: drive/MyDrive/test_data/test/06745.png
#  extracting: drive/MyDrive/test_data/test/06746.png
#  extracting: drive/MyDrive/test_data/test/06747.png
#   inflating: drive/MyDrive/test_data/test/06748.png
#  extracting: drive/MyDrive/test_data/test/06749.png
#   inflating: drive/MyDrive/test_data/test/06750.png
#   inflating: drive/MyDrive/test_data/test/06751.png
#   inflating: drive/MyDrive/test_data/test/06752.png
#   inflating: drive/MyDrive/test_data/test/06753.png
#   inflating: drive/MyDrive/test_data/test/06754.png
#   inflating: drive/MyDrive/test_data/test/06755.png
#   inflating: drive/MyDrive/test_data/test/06756.png
#   inflating: drive/MyDrive/test_data/test/06757.png
#   inflating: drive/MyDrive/test_data/test/06758.png
#   inflating: drive/MyDrive/test_data/test/06759.png
#   inflating: drive/MyDrive/test_data/test/06760.png
#   inflating: drive/MyDrive/test_data/test/06761.png
#   inflating: drive/MyDrive/test_data/test/06762.png
#   inflating: drive/MyDrive/test_data/test/06763.png
#   inflating: drive/MyDrive/test_data/test/06764.png
#   inflating: drive/MyDrive/test_data/test/06765.png
#  extracting: drive/MyDrive/test_data/test/06766.png
#   inflating: drive/MyDrive/test_data/test/06767.png
#   inflating: drive/MyDrive/test_data/test/06768.png
#   inflating: drive/MyDrive/test_data/test/06769.png
#   inflating: drive/MyDrive/test_data/test/06770.png
#   inflating: drive/MyDrive/test_data/test/06771.png
#  extracting: drive/MyDrive/test_data/test/06772.png
#  extracting: drive/MyDrive/test_data/test/06773.png
#   inflating: drive/MyDrive/test_data/test/06774.png
#   inflating: drive/MyDrive/test_data/test/06775.png
#   inflating: drive/MyDrive/test_data/test/06776.png
#   inflating: drive/MyDrive/test_data/test/06777.png
#  extracting: drive/MyDrive/test_data/test/06778.png
#   inflating: drive/MyDrive/test_data/test/06779.png
#   inflating: drive/MyDrive/test_data/test/06780.png
#   inflating: drive/MyDrive/test_data/test/06781.png
#   inflating: drive/MyDrive/test_data/test/06782.png
#   inflating: drive/MyDrive/test_data/test/06783.png
#  extracting: drive/MyDrive/test_data/test/06784.png
#   inflating: drive/MyDrive/test_data/test/06785.png
#   inflating: drive/MyDrive/test_data/test/06786.png
#  extracting: drive/MyDrive/test_data/test/06787.png
#   inflating: drive/MyDrive/test_data/test/06788.png
#   inflating: drive/MyDrive/test_data/test/06789.png
#   inflating: drive/MyDrive/test_data/test/06790.png
#  extracting: drive/MyDrive/test_data/test/06791.png
#   inflating: drive/MyDrive/test_data/test/06792.png
#   inflating: drive/MyDrive/test_data/test/06793.png
#  extracting: drive/MyDrive/test_data/test/06794.png
#   inflating: drive/MyDrive/test_data/test/06795.png
#   inflating: drive/MyDrive/test_data/test/06796.png
#   inflating: drive/MyDrive/test_data/test/06797.png
#   inflating: drive/MyDrive/test_data/test/06798.png
#   inflating: drive/MyDrive/test_data/test/06799.png
#   inflating: drive/MyDrive/test_data/test/06800.png
#   inflating: drive/MyDrive/test_data/test/06801.png
#   inflating: drive/MyDrive/test_data/test/06802.png
#   inflating: drive/MyDrive/test_data/test/06803.png
#   inflating: drive/MyDrive/test_data/test/06804.png
#   inflating: drive/MyDrive/test_data/test/06805.png
#   inflating: drive/MyDrive/test_data/test/06806.png
#   inflating: drive/MyDrive/test_data/test/06807.png
#   inflating: drive/MyDrive/test_data/test/06808.png
#   inflating: drive/MyDrive/test_data/test/06809.png
#   inflating: drive/MyDrive/test_data/test/06810.png
#   inflating: drive/MyDrive/test_data/test/06811.png
#   inflating: drive/MyDrive/test_data/test/06812.png
#  extracting: drive/MyDrive/test_data/test/06813.png
#  extracting: drive/MyDrive/test_data/test/06814.png
#   inflating: drive/MyDrive/test_data/test/06815.png
#   inflating: drive/MyDrive/test_data/test/06816.png
#  extracting: drive/MyDrive/test_data/test/06817.png
#   inflating: drive/MyDrive/test_data/test/06818.png
#   inflating: drive/MyDrive/test_data/test/06819.png
#   inflating: drive/MyDrive/test_data/test/06820.png
#   inflating: drive/MyDrive/test_data/test/06821.png
#   inflating: drive/MyDrive/test_data/test/06822.png
#  extracting: drive/MyDrive/test_data/test/06823.png
#   inflating: drive/MyDrive/test_data/test/06824.png
#   inflating: drive/MyDrive/test_data/test/06825.png
#  extracting: drive/MyDrive/test_data/test/06826.png
#   inflating: drive/MyDrive/test_data/test/06827.png
#   inflating: drive/MyDrive/test_data/test/06828.png
#   inflating: drive/MyDrive/test_data/test/06829.png
#   inflating: drive/MyDrive/test_data/test/06830.png
#  extracting: drive/MyDrive/test_data/test/06831.png
#   inflating: drive/MyDrive/test_data/test/06832.png
#   inflating: drive/MyDrive/test_data/test/06833.png
#   inflating: drive/MyDrive/test_data/test/06834.png
#   inflating: drive/MyDrive/test_data/test/06835.png
#   inflating: drive/MyDrive/test_data/test/06836.png
#   inflating: drive/MyDrive/test_data/test/06837.png
#   inflating: drive/MyDrive/test_data/test/06838.png
#   inflating: drive/MyDrive/test_data/test/06839.png
#   inflating: drive/MyDrive/test_data/test/06840.png
#  extracting: drive/MyDrive/test_data/test/06841.png
#   inflating: drive/MyDrive/test_data/test/06842.png
#   inflating: drive/MyDrive/test_data/test/06843.png
#   inflating: drive/MyDrive/test_data/test/06844.png
#   inflating: drive/MyDrive/test_data/test/06845.png
#   inflating: drive/MyDrive/test_data/test/06846.png
#  extracting: drive/MyDrive/test_data/test/06847.png
#  extracting: drive/MyDrive/test_data/test/06848.png
#   inflating: drive/MyDrive/test_data/test/06849.png
#   inflating: drive/MyDrive/test_data/test/06850.png
#  extracting: drive/MyDrive/test_data/test/06851.png
#   inflating: drive/MyDrive/test_data/test/06852.png
#   inflating: drive/MyDrive/test_data/test/06853.png
#  extracting: drive/MyDrive/test_data/test/06854.png
#   inflating: drive/MyDrive/test_data/test/06855.png
#   inflating: drive/MyDrive/test_data/test/06856.png
#   inflating: drive/MyDrive/test_data/test/06857.png
#   inflating: drive/MyDrive/test_data/test/06859.png
#   inflating: drive/MyDrive/test_data/test/06860.png
#   inflating: drive/MyDrive/test_data/test/06861.png
#   inflating: drive/MyDrive/test_data/test/06862.png
#  extracting: drive/MyDrive/test_data/test/06863.png
#   inflating: drive/MyDrive/test_data/test/06864.png
#   inflating: drive/MyDrive/test_data/test/06865.png
#   inflating: drive/MyDrive/test_data/test/06866.png
#   inflating: drive/MyDrive/test_data/test/06867.png
#   inflating: drive/MyDrive/test_data/test/06868.png
#   inflating: drive/MyDrive/test_data/test/06869.png
#   inflating: drive/MyDrive/test_data/test/06870.png
#   inflating: drive/MyDrive/test_data/test/06871.png
#   inflating: drive/MyDrive/test_data/test/06872.png
#  extracting: drive/MyDrive/test_data/test/06873.png
#   inflating: drive/MyDrive/test_data/test/06874.png
#   inflating: drive/MyDrive/test_data/test/06875.png
#   inflating: drive/MyDrive/test_data/test/06876.png
#  extracting: drive/MyDrive/test_data/test/06877.png
#   inflating: drive/MyDrive/test_data/test/06878.png
#   inflating: drive/MyDrive/test_data/test/06879.png
#   inflating: drive/MyDrive/test_data/test/06880.png
#   inflating: drive/MyDrive/test_data/test/06881.png
#   inflating: drive/MyDrive/test_data/test/06882.png
#   inflating: drive/MyDrive/test_data/test/06883.png
#   inflating: drive/MyDrive/test_data/test/06884.png
#   inflating: drive/MyDrive/test_data/test/06885.png
#   inflating: drive/MyDrive/test_data/test/06886.png
#  extracting: drive/MyDrive/test_data/test/06887.png
#   inflating: drive/MyDrive/test_data/test/06888.png
#   inflating: drive/MyDrive/test_data/test/06889.png
#   inflating: drive/MyDrive/test_data/test/06890.png
#   inflating: drive/MyDrive/test_data/test/06891.png
#   inflating: drive/MyDrive/test_data/test/06892.png
#   inflating: drive/MyDrive/test_data/test/06893.png
#   inflating: drive/MyDrive/test_data/test/06894.png
#   inflating: drive/MyDrive/test_data/test/06895.png
#   inflating: drive/MyDrive/test_data/test/06896.png
#  extracting: drive/MyDrive/test_data/test/06897.png
#   inflating: drive/MyDrive/test_data/test/06898.png
#   inflating: drive/MyDrive/test_data/test/06899.png
#   inflating: drive/MyDrive/test_data/test/06900.png
#  extracting: drive/MyDrive/test_data/test/06901.png
#  extracting: drive/MyDrive/test_data/test/06902.png
#   inflating: drive/MyDrive/test_data/test/06903.png
#   inflating: drive/MyDrive/test_data/test/06904.png
#  extracting: drive/MyDrive/test_data/test/06905.png
#   inflating: drive/MyDrive/test_data/test/06906.png
#  extracting: drive/MyDrive/test_data/test/06907.png
#  extracting: drive/MyDrive/test_data/test/06908.png
#  extracting: drive/MyDrive/test_data/test/06909.png
#   inflating: drive/MyDrive/test_data/test/06910.png
#   inflating: drive/MyDrive/test_data/test/06911.png
#   inflating: drive/MyDrive/test_data/test/06912.png
#   inflating: drive/MyDrive/test_data/test/06913.png
#   inflating: drive/MyDrive/test_data/test/06914.png
#   inflating: drive/MyDrive/test_data/test/06915.png
#   inflating: drive/MyDrive/test_data/test/06916.png
#   inflating: drive/MyDrive/test_data/test/06917.png
#   inflating: drive/MyDrive/test_data/test/06918.png
#  extracting: drive/MyDrive/test_data/test/06919.png
#   inflating: drive/MyDrive/test_data/test/06920.png
#   inflating: drive/MyDrive/test_data/test/06921.png
#   inflating: drive/MyDrive/test_data/test/06922.png
#   inflating: drive/MyDrive/test_data/test/06923.png
#   inflating: drive/MyDrive/test_data/test/06924.png
#   inflating: drive/MyDrive/test_data/test/06925.png
#   inflating: drive/MyDrive/test_data/test/06926.png
#   inflating: drive/MyDrive/test_data/test/06927.png
#   inflating: drive/MyDrive/test_data/test/06928.png
#  extracting: drive/MyDrive/test_data/test/06929.png
#   inflating: drive/MyDrive/test_data/test/06930.png
#   inflating: drive/MyDrive/test_data/test/06931.png
#   inflating: drive/MyDrive/test_data/test/06932.png
#   inflating: drive/MyDrive/test_data/test/06933.png
#   inflating: drive/MyDrive/test_data/test/06934.png
#   inflating: drive/MyDrive/test_data/test/06935.png
#   inflating: drive/MyDrive/test_data/test/06936.png
#   inflating: drive/MyDrive/test_data/test/06937.png
#   inflating: drive/MyDrive/test_data/test/06938.png
#   inflating: drive/MyDrive/test_data/test/06939.png
#   inflating: drive/MyDrive/test_data/test/06940.png
#   inflating: drive/MyDrive/test_data/test/06941.png
#  extracting: drive/MyDrive/test_data/test/06942.png
#  extracting: drive/MyDrive/test_data/test/06943.png
#   inflating: drive/MyDrive/test_data/test/06944.png
#   inflating: drive/MyDrive/test_data/test/06945.png
#  extracting: drive/MyDrive/test_data/test/06946.png
#   inflating: drive/MyDrive/test_data/test/06947.png
#   inflating: drive/MyDrive/test_data/test/06948.png
#  extracting: drive/MyDrive/test_data/test/06949.png
#  extracting: drive/MyDrive/test_data/test/06950.png
#  extracting: drive/MyDrive/test_data/test/06951.png
#   inflating: drive/MyDrive/test_data/test/06952.png
#   inflating: drive/MyDrive/test_data/test/06953.png
#  extracting: drive/MyDrive/test_data/test/06954.png
#   inflating: drive/MyDrive/test_data/test/06955.png
#   inflating: drive/MyDrive/test_data/test/06956.png
#   inflating: drive/MyDrive/test_data/test/06957.png
#  extracting: drive/MyDrive/test_data/test/06958.png
#   inflating: drive/MyDrive/test_data/test/06959.png
#   inflating: drive/MyDrive/test_data/test/06960.png
#   inflating: drive/MyDrive/test_data/test/06961.png
#   inflating: drive/MyDrive/test_data/test/06962.png
#  extracting: drive/MyDrive/test_data/test/06963.png
#   inflating: drive/MyDrive/test_data/test/06964.png
#   inflating: drive/MyDrive/test_data/test/06965.png
#   inflating: drive/MyDrive/test_data/test/06966.png
#   inflating: drive/MyDrive/test_data/test/06967.png
#   inflating: drive/MyDrive/test_data/test/06968.png
#   inflating: drive/MyDrive/test_data/test/06969.png
#   inflating: drive/MyDrive/test_data/test/06970.png
#  extracting: drive/MyDrive/test_data/test/06971.png
#   inflating: drive/MyDrive/test_data/test/06972.png
#   inflating: drive/MyDrive/test_data/test/06973.png
#   inflating: drive/MyDrive/test_data/test/06974.png
#  extracting: drive/MyDrive/test_data/test/06975.png
#   inflating: drive/MyDrive/test_data/test/06976.png
#   inflating: drive/MyDrive/test_data/test/06977.png
#   inflating: drive/MyDrive/test_data/test/06978.png
#   inflating: drive/MyDrive/test_data/test/06979.png
#  extracting: drive/MyDrive/test_data/test/06980.png
#  extracting: drive/MyDrive/test_data/test/06981.png
#  extracting: drive/MyDrive/test_data/test/06982.png
#  extracting: drive/MyDrive/test_data/test/06983.png
#  extracting: drive/MyDrive/test_data/test/06984.png
#   inflating: drive/MyDrive/test_data/test/06985.png
#  extracting: drive/MyDrive/test_data/test/06986.png
#   inflating: drive/MyDrive/test_data/test/06987.png
#   inflating: drive/MyDrive/test_data/test/06988.png
#   inflating: drive/MyDrive/test_data/test/06989.png
#  extracting: drive/MyDrive/test_data/test/06990.png
#   inflating: drive/MyDrive/test_data/test/06991.png
#   inflating: drive/MyDrive/test_data/test/06992.png
#   inflating: drive/MyDrive/test_data/test/06993.png
#   inflating: drive/MyDrive/test_data/test/06994.png
#  extracting: drive/MyDrive/test_data/test/06995.png
#   inflating: drive/MyDrive/test_data/test/06996.png
#   inflating: drive/MyDrive/test_data/test/06997.png
#  extracting: drive/MyDrive/test_data/test/06998.png
#   inflating: drive/MyDrive/test_data/test/06999.png
#  extracting: drive/MyDrive/test_data/test/07000.png
#  extracting: drive/MyDrive/test_data/test/07001.png
#   inflating: drive/MyDrive/test_data/test/07002.png
#   inflating: drive/MyDrive/test_data/test/07003.png
#  extracting: drive/MyDrive/test_data/test/07004.png
#   inflating: drive/MyDrive/test_data/test/07005.png
#   inflating: drive/MyDrive/test_data/test/07006.png
#  extracting: drive/MyDrive/test_data/test/07007.png
#   inflating: drive/MyDrive/test_data/test/07008.png
#   inflating: drive/MyDrive/test_data/test/07009.png
#   inflating: drive/MyDrive/test_data/test/07010.png
#   inflating: drive/MyDrive/test_data/test/07011.png
#   inflating: drive/MyDrive/test_data/test/07012.png
#   inflating: drive/MyDrive/test_data/test/07013.png
#   inflating: drive/MyDrive/test_data/test/07014.png
#   inflating: drive/MyDrive/test_data/test/07015.png
#  extracting: drive/MyDrive/test_data/test/07016.png
#   inflating: drive/MyDrive/test_data/test/07017.png
#   inflating: drive/MyDrive/test_data/test/07018.png
#   inflating: drive/MyDrive/test_data/test/07019.png
#   inflating: drive/MyDrive/test_data/test/07020.png
#   inflating: drive/MyDrive/test_data/test/07021.png
#   inflating: drive/MyDrive/test_data/test/07022.png
#  extracting: drive/MyDrive/test_data/test/07023.png
#   inflating: drive/MyDrive/test_data/test/07024.png
#   inflating: drive/MyDrive/test_data/test/07025.png
#   inflating: drive/MyDrive/test_data/test/07026.png
#   inflating: drive/MyDrive/test_data/test/07027.png
#   inflating: drive/MyDrive/test_data/test/07028.png
#   inflating: drive/MyDrive/test_data/test/07029.png
#   inflating: drive/MyDrive/test_data/test/07030.png
#   inflating: drive/MyDrive/test_data/test/07031.png
#   inflating: drive/MyDrive/test_data/test/07032.png
#  extracting: drive/MyDrive/test_data/test/07033.png
#   inflating: drive/MyDrive/test_data/test/07034.png
#   inflating: drive/MyDrive/test_data/test/07035.png
#   inflating: drive/MyDrive/test_data/test/07036.png
#   inflating: drive/MyDrive/test_data/test/07037.png
#  extracting: drive/MyDrive/test_data/test/07038.png
#   inflating: drive/MyDrive/test_data/test/07039.png
#   inflating: drive/MyDrive/test_data/test/07040.png
#   inflating: drive/MyDrive/test_data/test/07041.png
#   inflating: drive/MyDrive/test_data/test/07042.png
#   inflating: drive/MyDrive/test_data/test/07043.png
#  extracting: drive/MyDrive/test_data/test/07044.png
#   inflating: drive/MyDrive/test_data/test/07045.png
#  extracting: drive/MyDrive/test_data/test/07046.png
#   inflating: drive/MyDrive/test_data/test/07047.png
#   inflating: drive/MyDrive/test_data/test/07048.png
#   inflating: drive/MyDrive/test_data/test/07049.png
#  extracting: drive/MyDrive/test_data/test/07050.png
#   inflating: drive/MyDrive/test_data/test/07051.png
#   inflating: drive/MyDrive/test_data/test/07052.png
#   inflating: drive/MyDrive/test_data/test/07053.png
#   inflating: drive/MyDrive/test_data/test/07054.png
#   inflating: drive/MyDrive/test_data/test/07055.png
#  extracting: drive/MyDrive/test_data/test/07056.png
#   inflating: drive/MyDrive/test_data/test/07057.png
#   inflating: drive/MyDrive/test_data/test/07058.png
#   inflating: drive/MyDrive/test_data/test/07059.png
#   inflating: drive/MyDrive/test_data/test/07060.png
#  extracting: drive/MyDrive/test_data/test/07061.png
#   inflating: drive/MyDrive/test_data/test/07062.png
#   inflating: drive/MyDrive/test_data/test/07063.png
#   inflating: drive/MyDrive/test_data/test/07064.png
#   inflating: drive/MyDrive/test_data/test/07065.png
#   inflating: drive/MyDrive/test_data/test/07066.png
#   inflating: drive/MyDrive/test_data/test/07067.png
#   inflating: drive/MyDrive/test_data/test/07068.png
#   inflating: drive/MyDrive/test_data/test/07069.png
#   inflating: drive/MyDrive/test_data/test/07070.png
#   inflating: drive/MyDrive/test_data/test/07071.png
#  extracting: drive/MyDrive/test_data/test/07072.png
#   inflating: drive/MyDrive/test_data/test/07073.png
#   inflating: drive/MyDrive/test_data/test/07074.png
#   inflating: drive/MyDrive/test_data/test/07075.png
#   inflating: drive/MyDrive/test_data/test/07076.png
#   inflating: drive/MyDrive/test_data/test/07077.png
#   inflating: drive/MyDrive/test_data/test/07078.png
#   inflating: drive/MyDrive/test_data/test/07079.png
#  extracting: drive/MyDrive/test_data/test/07080.png
#   inflating: drive/MyDrive/test_data/test/07081.png
#   inflating: drive/MyDrive/test_data/test/07082.png
#  extracting: drive/MyDrive/test_data/test/07083.png
#   inflating: drive/MyDrive/test_data/test/07084.png
#   inflating: drive/MyDrive/test_data/test/07085.png
#   inflating: drive/MyDrive/test_data/test/07086.png
#   inflating: drive/MyDrive/test_data/test/07087.png
#   inflating: drive/MyDrive/test_data/test/07088.png
#   inflating: drive/MyDrive/test_data/test/07089.png
#   inflating: drive/MyDrive/test_data/test/07090.png
#   inflating: drive/MyDrive/test_data/test/07091.png
#  extracting: drive/MyDrive/test_data/test/07092.png
#   inflating: drive/MyDrive/test_data/test/07093.png
#   inflating: drive/MyDrive/test_data/test/07094.png
#  extracting: drive/MyDrive/test_data/test/07095.png
#  extracting: drive/MyDrive/test_data/test/07096.png
#   inflating: drive/MyDrive/test_data/test/07097.png
#   inflating: drive/MyDrive/test_data/test/07098.png
#   inflating: drive/MyDrive/test_data/test/07099.png
#   inflating: drive/MyDrive/test_data/test/07100.png
#   inflating: drive/MyDrive/test_data/test/07101.png
#  extracting: drive/MyDrive/test_data/test/07102.png
#  extracting: drive/MyDrive/test_data/test/07103.png
#   inflating: drive/MyDrive/test_data/test/07104.png
#   inflating: drive/MyDrive/test_data/test/07105.png
#  extracting: drive/MyDrive/test_data/test/07106.png
#   inflating: drive/MyDrive/test_data/test/07107.png
#  extracting: drive/MyDrive/test_data/test/07108.png
#   inflating: drive/MyDrive/test_data/test/07109.png
#  extracting: drive/MyDrive/test_data/test/07110.png
#  extracting: drive/MyDrive/test_data/test/07111.png
#   inflating: drive/MyDrive/test_data/test/07112.png
#   inflating: drive/MyDrive/test_data/test/07113.png
#   inflating: drive/MyDrive/test_data/test/07114.png
#   inflating: drive/MyDrive/test_data/test/07115.png
#   inflating: drive/MyDrive/test_data/test/07116.png
#   inflating: drive/MyDrive/test_data/test/07117.png
#  extracting: drive/MyDrive/test_data/test/07118.png
#  extracting: drive/MyDrive/test_data/test/07119.png
#   inflating: drive/MyDrive/test_data/test/07120.png
#   inflating: drive/MyDrive/test_data/test/07121.png
#   inflating: drive/MyDrive/test_data/test/07122.png
#   inflating: drive/MyDrive/test_data/test/07123.png
#  extracting: drive/MyDrive/test_data/test/07124.png
#   inflating: drive/MyDrive/test_data/test/07125.png
#  extracting: drive/MyDrive/test_data/test/07126.png
#   inflating: drive/MyDrive/test_data/test/07127.png
#   inflating: drive/MyDrive/test_data/test/07128.png
#   inflating: drive/MyDrive/test_data/test/07129.png
#   inflating: drive/MyDrive/test_data/test/07130.png
#  extracting: drive/MyDrive/test_data/test/07131.png
#   inflating: drive/MyDrive/test_data/test/07132.png
#  extracting: drive/MyDrive/test_data/test/07133.png
#   inflating: drive/MyDrive/test_data/test/07134.png
#   inflating: drive/MyDrive/test_data/test/07135.png
#   inflating: drive/MyDrive/test_data/test/07136.png
#   inflating: drive/MyDrive/test_data/test/07137.png
#  extracting: drive/MyDrive/test_data/test/07138.png
#   inflating: drive/MyDrive/test_data/test/07139.png
#   inflating: drive/MyDrive/test_data/test/07140.png
#   inflating: drive/MyDrive/test_data/test/07141.png
#   inflating: drive/MyDrive/test_data/test/07142.png
#   inflating: drive/MyDrive/test_data/test/07143.png
#   inflating: drive/MyDrive/test_data/test/07144.png
#  extracting: drive/MyDrive/test_data/test/07145.png
#   inflating: drive/MyDrive/test_data/test/07146.png
#   inflating: drive/MyDrive/test_data/test/07147.png
#   inflating: drive/MyDrive/test_data/test/07148.png
#   inflating: drive/MyDrive/test_data/test/07149.png
#   inflating: drive/MyDrive/test_data/test/07150.png
#   inflating: drive/MyDrive/test_data/test/07151.png
#   inflating: drive/MyDrive/test_data/test/07152.png
#   inflating: drive/MyDrive/test_data/test/07153.png
#   inflating: drive/MyDrive/test_data/test/07154.png
#   inflating: drive/MyDrive/test_data/test/07155.png
#   inflating: drive/MyDrive/test_data/test/07156.png
#   inflating: drive/MyDrive/test_data/test/07157.png
#   inflating: drive/MyDrive/test_data/test/07158.png
#   inflating: drive/MyDrive/test_data/test/07159.png
#   inflating: drive/MyDrive/test_data/test/07160.png
#   inflating: drive/MyDrive/test_data/test/07161.png
#   inflating: drive/MyDrive/test_data/test/07162.png
#   inflating: drive/MyDrive/test_data/test/07163.png
#  extracting: drive/MyDrive/test_data/test/07164.png
#   inflating: drive/MyDrive/test_data/test/07165.png
#   inflating: drive/MyDrive/test_data/test/07166.png
#  extracting: drive/MyDrive/test_data/test/07167.png
#  extracting: drive/MyDrive/test_data/test/07168.png
#   inflating: drive/MyDrive/test_data/test/07169.png
#   inflating: drive/MyDrive/test_data/test/07170.png
#   inflating: drive/MyDrive/test_data/test/07171.png
#   inflating: drive/MyDrive/test_data/test/07172.png
#  extracting: drive/MyDrive/test_data/test/07173.png
#   inflating: drive/MyDrive/test_data/test/07174.png
#   inflating: drive/MyDrive/test_data/test/07175.png
#   inflating: drive/MyDrive/test_data/test/07176.png
#  extracting: drive/MyDrive/test_data/test/07177.png
#   inflating: drive/MyDrive/test_data/test/07178.png
#   inflating: drive/MyDrive/test_data/test/07179.png
#  extracting: drive/MyDrive/test_data/test/07180.png
#   inflating: drive/MyDrive/test_data/test/07181.png
#   inflating: drive/MyDrive/test_data/test/07182.png
#   inflating: drive/MyDrive/test_data/test/07183.png
#   inflating: drive/MyDrive/test_data/test/07184.png
#   inflating: drive/MyDrive/test_data/test/07185.png
#   inflating: drive/MyDrive/test_data/test/07186.png
#   inflating: drive/MyDrive/test_data/test/07187.png
#   inflating: drive/MyDrive/test_data/test/07188.png
#   inflating: drive/MyDrive/test_data/test/07189.png
#  extracting: drive/MyDrive/test_data/test/07190.png
#   inflating: drive/MyDrive/test_data/test/07191.png
#   inflating: drive/MyDrive/test_data/test/07192.png
#   inflating: drive/MyDrive/test_data/test/07193.png
#   inflating: drive/MyDrive/test_data/test/07194.png
#   inflating: drive/MyDrive/test_data/test/07195.png
#   inflating: drive/MyDrive/test_data/test/07196.png
#   inflating: drive/MyDrive/test_data/test/07197.png
#   inflating: drive/MyDrive/test_data/test/07198.png
#  extracting: drive/MyDrive/test_data/test/07199.png
#   inflating: drive/MyDrive/test_data/test/07200.png
#  extracting: drive/MyDrive/test_data/test/07201.png
#   inflating: drive/MyDrive/test_data/test/07202.png
#  extracting: drive/MyDrive/test_data/test/07203.png
#   inflating: drive/MyDrive/test_data/test/07204.png
#  extracting: drive/MyDrive/test_data/test/07205.png
#  extracting: drive/MyDrive/test_data/test/07206.png
#   inflating: drive/MyDrive/test_data/test/07207.png
#   inflating: drive/MyDrive/test_data/test/07208.png
#   inflating: drive/MyDrive/test_data/test/07209.png
#   inflating: drive/MyDrive/test_data/test/07210.png
#   inflating: drive/MyDrive/test_data/test/07211.png
#   inflating: drive/MyDrive/test_data/test/07212.png
#   inflating: drive/MyDrive/test_data/test/07213.png
#  extracting: drive/MyDrive/test_data/test/07214.png
#  extracting: drive/MyDrive/test_data/test/07215.png
#  extracting: drive/MyDrive/test_data/test/07216.png
#  extracting: drive/MyDrive/test_data/test/07217.png
#  extracting: drive/MyDrive/test_data/test/07218.png
#   inflating: drive/MyDrive/test_data/test/07219.png
#   inflating: drive/MyDrive/test_data/test/07220.png
#  extracting: drive/MyDrive/test_data/test/07221.png
#   inflating: drive/MyDrive/test_data/test/07222.png
#   inflating: drive/MyDrive/test_data/test/07223.png
#   inflating: drive/MyDrive/test_data/test/07224.png
#   inflating: drive/MyDrive/test_data/test/07225.png
#   inflating: drive/MyDrive/test_data/test/07226.png
#   inflating: drive/MyDrive/test_data/test/07227.png
#  extracting: drive/MyDrive/test_data/test/07228.png
#   inflating: drive/MyDrive/test_data/test/07229.png
#   inflating: drive/MyDrive/test_data/test/07230.png
#   inflating: drive/MyDrive/test_data/test/07231.png
#   inflating: drive/MyDrive/test_data/test/07232.png
#   inflating: drive/MyDrive/test_data/test/07233.png
#   inflating: drive/MyDrive/test_data/test/07234.png
#   inflating: drive/MyDrive/test_data/test/07235.png
#   inflating: drive/MyDrive/test_data/test/07236.png
#  extracting: drive/MyDrive/test_data/test/07237.png
#   inflating: drive/MyDrive/test_data/test/07238.png
#   inflating: drive/MyDrive/test_data/test/07239.png
#   inflating: drive/MyDrive/test_data/test/07240.png
#   inflating: drive/MyDrive/test_data/test/07241.png
#   inflating: drive/MyDrive/test_data/test/07242.png
#   inflating: drive/MyDrive/test_data/test/07243.png
#   inflating: drive/MyDrive/test_data/test/07244.png
#   inflating: drive/MyDrive/test_data/test/07245.png
#   inflating: drive/MyDrive/test_data/test/07246.png
#  extracting: drive/MyDrive/test_data/test/07247.png
#   inflating: drive/MyDrive/test_data/test/07248.png
#  extracting: drive/MyDrive/test_data/test/07249.png
#   inflating: drive/MyDrive/test_data/test/07250.png
#  extracting: drive/MyDrive/test_data/test/07251.png
#   inflating: drive/MyDrive/test_data/test/07252.png
#   inflating: drive/MyDrive/test_data/test/07253.png
#  extracting: drive/MyDrive/test_data/test/07254.png
#   inflating: drive/MyDrive/test_data/test/07255.png
#   inflating: drive/MyDrive/test_data/test/07256.png
#   inflating: drive/MyDrive/test_data/test/07257.png
#  extracting: drive/MyDrive/test_data/test/07258.png
#   inflating: drive/MyDrive/test_data/test/07259.png
#   inflating: drive/MyDrive/test_data/test/07260.png
#   inflating: drive/MyDrive/test_data/test/07261.png
#  extracting: drive/MyDrive/test_data/test/07262.png
#   inflating: drive/MyDrive/test_data/test/07263.png
#   inflating: drive/MyDrive/test_data/test/07264.png
#   inflating: drive/MyDrive/test_data/test/07265.png
#   inflating: drive/MyDrive/test_data/test/07266.png
#   inflating: drive/MyDrive/test_data/test/07267.png
#   inflating: drive/MyDrive/test_data/test/07268.png
#   inflating: drive/MyDrive/test_data/test/07269.png
#   inflating: drive/MyDrive/test_data/test/07270.png
#   inflating: drive/MyDrive/test_data/test/07271.png
#   inflating: drive/MyDrive/test_data/test/07272.png
#   inflating: drive/MyDrive/test_data/test/07273.png
#   inflating: drive/MyDrive/test_data/test/07274.png
#   inflating: drive/MyDrive/test_data/test/07275.png
#   inflating: drive/MyDrive/test_data/test/07276.png
#   inflating: drive/MyDrive/test_data/test/07277.png
#   inflating: drive/MyDrive/test_data/test/07278.png
#   inflating: drive/MyDrive/test_data/test/07279.png
#   inflating: drive/MyDrive/test_data/test/07280.png
#  extracting: drive/MyDrive/test_data/test/07281.png
#  extracting: drive/MyDrive/test_data/test/07282.png
#   inflating: drive/MyDrive/test_data/test/07283.png
#   inflating: drive/MyDrive/test_data/test/07284.png
#   inflating: drive/MyDrive/test_data/test/07285.png
#   inflating: drive/MyDrive/test_data/test/07286.png
#  extracting: drive/MyDrive/test_data/test/07287.png
#   inflating: drive/MyDrive/test_data/test/07288.png
#   inflating: drive/MyDrive/test_data/test/07289.png
#   inflating: drive/MyDrive/test_data/test/07290.png
#   inflating: drive/MyDrive/test_data/test/07291.png
#   inflating: drive/MyDrive/test_data/test/07292.png
#   inflating: drive/MyDrive/test_data/test/07293.png
#  extracting: drive/MyDrive/test_data/test/07294.png
#   inflating: drive/MyDrive/test_data/test/07295.png
#   inflating: drive/MyDrive/test_data/test/07296.png
#   inflating: drive/MyDrive/test_data/test/07297.png
#   inflating: drive/MyDrive/test_data/test/07298.png
#   inflating: drive/MyDrive/test_data/test/07299.png
#   inflating: drive/MyDrive/test_data/test/07300.png
#   inflating: drive/MyDrive/test_data/test/07301.png
#   inflating: drive/MyDrive/test_data/test/07302.png
#   inflating: drive/MyDrive/test_data/test/07303.png
#  extracting: drive/MyDrive/test_data/test/07304.png
#  extracting: drive/MyDrive/test_data/test/07305.png
#  extracting: drive/MyDrive/test_data/test/07306.png
#  extracting: drive/MyDrive/test_data/test/07307.png
#   inflating: drive/MyDrive/test_data/test/07308.png
#  extracting: drive/MyDrive/test_data/test/07309.png
#   inflating: drive/MyDrive/test_data/test/07310.png
#   inflating: drive/MyDrive/test_data/test/07311.png
#   inflating: drive/MyDrive/test_data/test/07312.png
#   inflating: drive/MyDrive/test_data/test/07313.png
#   inflating: drive/MyDrive/test_data/test/07314.png
#   inflating: drive/MyDrive/test_data/test/07315.png
#   inflating: drive/MyDrive/test_data/test/07316.png
#   inflating: drive/MyDrive/test_data/test/07317.png
#   inflating: drive/MyDrive/test_data/test/07318.png
#   inflating: drive/MyDrive/test_data/test/07319.png
#  extracting: drive/MyDrive/test_data/test/07320.png
#   inflating: drive/MyDrive/test_data/test/07321.png
#   inflating: drive/MyDrive/test_data/test/07322.png
#   inflating: drive/MyDrive/test_data/test/07323.png
#   inflating: drive/MyDrive/test_data/test/07324.png
#   inflating: drive/MyDrive/test_data/test/07325.png
#   inflating: drive/MyDrive/test_data/test/07326.png
#   inflating: drive/MyDrive/test_data/test/07327.png
#   inflating: drive/MyDrive/test_data/test/07328.png
#  extracting: drive/MyDrive/test_data/test/07329.png
#   inflating: drive/MyDrive/test_data/test/07330.png
#   inflating: drive/MyDrive/test_data/test/07331.png
#   inflating: drive/MyDrive/test_data/test/07332.png
#   inflating: drive/MyDrive/test_data/test/07333.png
#   inflating: drive/MyDrive/test_data/test/07334.png
#   inflating: drive/MyDrive/test_data/test/07335.png
#   inflating: drive/MyDrive/test_data/test/07336.png
#   inflating: drive/MyDrive/test_data/test/07337.png
#   inflating: drive/MyDrive/test_data/test/07338.png
#   inflating: drive/MyDrive/test_data/test/07339.png
#   inflating: drive/MyDrive/test_data/test/07340.png
#   inflating: drive/MyDrive/test_data/test/07341.png
#   inflating: drive/MyDrive/test_data/test/07342.png
#   inflating: drive/MyDrive/test_data/test/07343.png
#   inflating: drive/MyDrive/test_data/test/07344.png
#   inflating: drive/MyDrive/test_data/test/07345.png
#   inflating: drive/MyDrive/test_data/test/07346.png
#   inflating: drive/MyDrive/test_data/test/07347.png
#   inflating: drive/MyDrive/test_data/test/07348.png
#   inflating: drive/MyDrive/test_data/test/07349.png
#   inflating: drive/MyDrive/test_data/test/07350.png
#   inflating: drive/MyDrive/test_data/test/07351.png
#  extracting: drive/MyDrive/test_data/test/07352.png
#   inflating: drive/MyDrive/test_data/test/07353.png
#   inflating: drive/MyDrive/test_data/test/07354.png
#   inflating: drive/MyDrive/test_data/test/07355.png
#  extracting: drive/MyDrive/test_data/test/07356.png
#   inflating: drive/MyDrive/test_data/test/07357.png
#   inflating: drive/MyDrive/test_data/test/07358.png
#   inflating: drive/MyDrive/test_data/test/07359.png
#  extracting: drive/MyDrive/test_data/test/07360.png
#   inflating: drive/MyDrive/test_data/test/07361.png
#  extracting: drive/MyDrive/test_data/test/07362.png
#   inflating: drive/MyDrive/test_data/test/07363.png
#   inflating: drive/MyDrive/test_data/test/07364.png
#   inflating: drive/MyDrive/test_data/test/07365.png
#  extracting: drive/MyDrive/test_data/test/07366.png
#   inflating: drive/MyDrive/test_data/test/07367.png
#   inflating: drive/MyDrive/test_data/test/07368.png
#  extracting: drive/MyDrive/test_data/test/07369.png
#   inflating: drive/MyDrive/test_data/test/07370.png
#  extracting: drive/MyDrive/test_data/test/07371.png
#   inflating: drive/MyDrive/test_data/test/07372.png
#   inflating: drive/MyDrive/test_data/test/07373.png
#   inflating: drive/MyDrive/test_data/test/07374.png
#   inflating: drive/MyDrive/test_data/test/07375.png
#  extracting: drive/MyDrive/test_data/test/07376.png
#  extracting: drive/MyDrive/test_data/test/07377.png
#   inflating: drive/MyDrive/test_data/test/07378.png
#  extracting: drive/MyDrive/test_data/test/07379.png
#   inflating: drive/MyDrive/test_data/test/07380.png
#  extracting: drive/MyDrive/test_data/test/07381.png
#   inflating: drive/MyDrive/test_data/test/07382.png
#  extracting: drive/MyDrive/test_data/test/07383.png
#   inflating: drive/MyDrive/test_data/test/07384.png
#   inflating: drive/MyDrive/test_data/test/07385.png
#   inflating: drive/MyDrive/test_data/test/07386.png
#   inflating: drive/MyDrive/test_data/test/07387.png
#   inflating: drive/MyDrive/test_data/test/07388.png
#   inflating: drive/MyDrive/test_data/test/07389.png
#   inflating: drive/MyDrive/test_data/test/07390.png
#   inflating: drive/MyDrive/test_data/test/07391.png
#   inflating: drive/MyDrive/test_data/test/07392.png
#   inflating: drive/MyDrive/test_data/test/07393.png
#   inflating: drive/MyDrive/test_data/test/07394.png
#  extracting: drive/MyDrive/test_data/test/07395.png
#   inflating: drive/MyDrive/test_data/test/07396.png
#   inflating: drive/MyDrive/test_data/test/07397.png
#  extracting: drive/MyDrive/test_data/test/07398.png
#  extracting: drive/MyDrive/test_data/test/07399.png
#  extracting: drive/MyDrive/test_data/test/07400.png
#  extracting: drive/MyDrive/test_data/test/07401.png
#   inflating: drive/MyDrive/test_data/test/07402.png
#   inflating: drive/MyDrive/test_data/test/07403.png
#  extracting: drive/MyDrive/test_data/test/07404.png
#   inflating: drive/MyDrive/test_data/test/07405.png
#   inflating: drive/MyDrive/test_data/test/07406.png
#   inflating: drive/MyDrive/test_data/test/07407.png
#  extracting: drive/MyDrive/test_data/test/07408.png
#   inflating: drive/MyDrive/test_data/test/07409.png
#   inflating: drive/MyDrive/test_data/test/07410.png
#   inflating: drive/MyDrive/test_data/test/07411.png
#   inflating: drive/MyDrive/test_data/test/07412.png
#   inflating: drive/MyDrive/test_data/test/07413.png
#   inflating: drive/MyDrive/test_data/test/07414.png
#   inflating: drive/MyDrive/test_data/test/07415.png
#   inflating: drive/MyDrive/test_data/test/07416.png
#  extracting: drive/MyDrive/test_data/test/07417.png
#   inflating: drive/MyDrive/test_data/test/07418.png
#  extracting: drive/MyDrive/test_data/test/07419.png
#   inflating: drive/MyDrive/test_data/test/07420.png
#   inflating: drive/MyDrive/test_data/test/07421.png
#   inflating: drive/MyDrive/test_data/test/07422.png
#   inflating: drive/MyDrive/test_data/test/07423.png
#   inflating: drive/MyDrive/test_data/test/07424.png
#   inflating: drive/MyDrive/test_data/test/07425.png
#   inflating: drive/MyDrive/test_data/test/07426.png
#   inflating: drive/MyDrive/test_data/test/07427.png
#   inflating: drive/MyDrive/test_data/test/07428.png
#   inflating: drive/MyDrive/test_data/test/07429.png
#   inflating: drive/MyDrive/test_data/test/07430.png
#  extracting: drive/MyDrive/test_data/test/07431.png
#   inflating: drive/MyDrive/test_data/test/07432.png
#   inflating: drive/MyDrive/test_data/test/07433.png
#   inflating: drive/MyDrive/test_data/test/07434.png
#  extracting: drive/MyDrive/test_data/test/07435.png
#   inflating: drive/MyDrive/test_data/test/07436.png
#   inflating: drive/MyDrive/test_data/test/07437.png
#   inflating: drive/MyDrive/test_data/test/07438.png
#   inflating: drive/MyDrive/test_data/test/07439.png
#   inflating: drive/MyDrive/test_data/test/07440.png
#   inflating: drive/MyDrive/test_data/test/07441.png
#   inflating: drive/MyDrive/test_data/test/07442.png
#   inflating: drive/MyDrive/test_data/test/07443.png
#   inflating: drive/MyDrive/test_data/test/07444.png
#   inflating: drive/MyDrive/test_data/test/07445.png
#   inflating: drive/MyDrive/test_data/test/07446.png
#  extracting: drive/MyDrive/test_data/test/07447.png
#   inflating: drive/MyDrive/test_data/test/07448.png
#  extracting: drive/MyDrive/test_data/test/07449.png
#  extracting: drive/MyDrive/test_data/test/07450.png
#  extracting: drive/MyDrive/test_data/test/07451.png
#   inflating: drive/MyDrive/test_data/test/07452.png
#   inflating: drive/MyDrive/test_data/test/07453.png
#   inflating: drive/MyDrive/test_data/test/07454.png
#   inflating: drive/MyDrive/test_data/test/07455.png
#  extracting: drive/MyDrive/test_data/test/07456.png
#  extracting: drive/MyDrive/test_data/test/07457.png
#   inflating: drive/MyDrive/test_data/test/07458.png
#   inflating: drive/MyDrive/test_data/test/07459.png
#   inflating: drive/MyDrive/test_data/test/07460.png
#   inflating: drive/MyDrive/test_data/test/07461.png
#  extracting: drive/MyDrive/test_data/test/07462.png
#  extracting: drive/MyDrive/test_data/test/07463.png
#   inflating: drive/MyDrive/test_data/test/07464.png
#   inflating: drive/MyDrive/test_data/test/07465.png
#  extracting: drive/MyDrive/test_data/test/07466.png
#   inflating: drive/MyDrive/test_data/test/07467.png
#   inflating: drive/MyDrive/test_data/test/07468.png
#   inflating: drive/MyDrive/test_data/test/07469.png
#   inflating: drive/MyDrive/test_data/test/07470.png
#   inflating: drive/MyDrive/test_data/test/07471.png
#  extracting: drive/MyDrive/test_data/test/07472.png
#   inflating: drive/MyDrive/test_data/test/07473.png
#   inflating: drive/MyDrive/test_data/test/07474.png
#  extracting: drive/MyDrive/test_data/test/07475.png
#   inflating: drive/MyDrive/test_data/test/07476.png
#  extracting: drive/MyDrive/test_data/test/07477.png
#   inflating: drive/MyDrive/test_data/test/07478.png
#   inflating: drive/MyDrive/test_data/test/07479.png
#   inflating: drive/MyDrive/test_data/test/07480.png
#   inflating: drive/MyDrive/test_data/test/07481.png
#   inflating: drive/MyDrive/test_data/test/07482.png
#  extracting: drive/MyDrive/test_data/test/07483.png
#   inflating: drive/MyDrive/test_data/test/07484.png
#   inflating: drive/MyDrive/test_data/test/07485.png
#   inflating: drive/MyDrive/test_data/test/07486.png
#  extracting: drive/MyDrive/test_data/test/07487.png
#   inflating: drive/MyDrive/test_data/test/07488.png
#   inflating: drive/MyDrive/test_data/test/07489.png
#   inflating: drive/MyDrive/test_data/test/07490.png
#   inflating: drive/MyDrive/test_data/test/07491.png
#   inflating: drive/MyDrive/test_data/test/07492.png
#   inflating: drive/MyDrive/test_data/test/07493.png
#   inflating: drive/MyDrive/test_data/test/07494.png
#   inflating: drive/MyDrive/test_data/test/07495.png
#  extracting: drive/MyDrive/test_data/test/07496.png
#   inflating: drive/MyDrive/test_data/test/07497.png
#  extracting: drive/MyDrive/test_data/test/07498.png
#  extracting: drive/MyDrive/test_data/test/07499.png
#   inflating: drive/MyDrive/test_data/test/07500.png
#   inflating: drive/MyDrive/test_data/test/07501.png
#  extracting: drive/MyDrive/test_data/test/07502.png
#   inflating: drive/MyDrive/test_data/test/07503.png
#  extracting: drive/MyDrive/test_data/test/07504.png
#  extracting: drive/MyDrive/test_data/test/07505.png
#   inflating: drive/MyDrive/test_data/test/07506.png
#   inflating: drive/MyDrive/test_data/test/07507.png
#   inflating: drive/MyDrive/test_data/test/07508.png
#   inflating: drive/MyDrive/test_data/test/07509.png
#   inflating: drive/MyDrive/test_data/test/07510.png
#   inflating: drive/MyDrive/test_data/test/07511.png
#  extracting: drive/MyDrive/test_data/test/07512.png
#   inflating: drive/MyDrive/test_data/test/07513.png
#  extracting: drive/MyDrive/test_data/test/07514.png
#  extracting: drive/MyDrive/test_data/test/07515.png
#   inflating: drive/MyDrive/test_data/test/07516.png
#  extracting: drive/MyDrive/test_data/test/07517.png
#  extracting: drive/MyDrive/test_data/test/07518.png
#   inflating: drive/MyDrive/test_data/test/07519.png
#   inflating: drive/MyDrive/test_data/test/07520.png
#   inflating: drive/MyDrive/test_data/test/07521.png
#   inflating: drive/MyDrive/test_data/test/07522.png
#  extracting: drive/MyDrive/test_data/test/07523.png
#   inflating: drive/MyDrive/test_data/test/07524.png
#   inflating: drive/MyDrive/test_data/test/07525.png
#   inflating: drive/MyDrive/test_data/test/07526.png
#   inflating: drive/MyDrive/test_data/test/07527.png
#   inflating: drive/MyDrive/test_data/test/07528.png
#   inflating: drive/MyDrive/test_data/test/07529.png
#   inflating: drive/MyDrive/test_data/test/07530.png
#   inflating: drive/MyDrive/test_data/test/07531.png
#   inflating: drive/MyDrive/test_data/test/07532.png
#  extracting: drive/MyDrive/test_data/test/07533.png
#   inflating: drive/MyDrive/test_data/test/07534.png
#   inflating: drive/MyDrive/test_data/test/07535.png
#   inflating: drive/MyDrive/test_data/test/07536.png
#  extracting: drive/MyDrive/test_data/test/07537.png
#   inflating: drive/MyDrive/test_data/test/07538.png
#   inflating: drive/MyDrive/test_data/test/07539.png
#   inflating: drive/MyDrive/test_data/test/07540.png
#  extracting: drive/MyDrive/test_data/test/07541.png
#   inflating: drive/MyDrive/test_data/test/07542.png
#   inflating: drive/MyDrive/test_data/test/07543.png
#  extracting: drive/MyDrive/test_data/test/07544.png
#   inflating: drive/MyDrive/test_data/test/07545.png
#   inflating: drive/MyDrive/test_data/test/07546.png
#   inflating: drive/MyDrive/test_data/test/07547.png
#   inflating: drive/MyDrive/test_data/test/07548.png
#   inflating: drive/MyDrive/test_data/test/07549.png
#   inflating: drive/MyDrive/test_data/test/07550.png
#   inflating: drive/MyDrive/test_data/test/07551.png
#   inflating: drive/MyDrive/test_data/test/07552.png
#   inflating: drive/MyDrive/test_data/test/07553.png
#   inflating: drive/MyDrive/test_data/test/07554.png
#   inflating: drive/MyDrive/test_data/test/07555.png
#   inflating: drive/MyDrive/test_data/test/07556.png
#   inflating: drive/MyDrive/test_data/test/07557.png
#   inflating: drive/MyDrive/test_data/test/07558.png
#   inflating: drive/MyDrive/test_data/test/07559.png
#   inflating: drive/MyDrive/test_data/test/07560.png
#  extracting: drive/MyDrive/test_data/test/07561.png
#   inflating: drive/MyDrive/test_data/test/07562.png
#   inflating: drive/MyDrive/test_data/test/07563.png
#   inflating: drive/MyDrive/test_data/test/07564.png
#  extracting: drive/MyDrive/test_data/test/07565.png
#   inflating: drive/MyDrive/test_data/test/07566.png
#   inflating: drive/MyDrive/test_data/test/07567.png
#   inflating: drive/MyDrive/test_data/test/07568.png
#   inflating: drive/MyDrive/test_data/test/07569.png
#   inflating: drive/MyDrive/test_data/test/07570.png
#  extracting: drive/MyDrive/test_data/test/07571.png
#   inflating: drive/MyDrive/test_data/test/07572.png
#  extracting: drive/MyDrive/test_data/test/07573.png
#   inflating: drive/MyDrive/test_data/test/07574.png
#   inflating: drive/MyDrive/test_data/test/07575.png
#   inflating: drive/MyDrive/test_data/test/07576.png
#   inflating: drive/MyDrive/test_data/test/07577.png
#   inflating: drive/MyDrive/test_data/test/07578.png
#   inflating: drive/MyDrive/test_data/test/07579.png
#   inflating: drive/MyDrive/test_data/test/07580.png
#   inflating: drive/MyDrive/test_data/test/07581.png
#   inflating: drive/MyDrive/test_data/test/07582.png
#   inflating: drive/MyDrive/test_data/test/07583.png
#   inflating: drive/MyDrive/test_data/test/07584.png
#   inflating: drive/MyDrive/test_data/test/07585.png
#   inflating: drive/MyDrive/test_data/test/07586.png
#   inflating: drive/MyDrive/test_data/test/07587.png
#   inflating: drive/MyDrive/test_data/test/07588.png
#   inflating: drive/MyDrive/test_data/test/07589.png
#   inflating: drive/MyDrive/test_data/test/07590.png
#   inflating: drive/MyDrive/test_data/test/07591.png
#   inflating: drive/MyDrive/test_data/test/07592.png
#   inflating: drive/MyDrive/test_data/test/07593.png
#   inflating: drive/MyDrive/test_data/test/07594.png
#   inflating: drive/MyDrive/test_data/test/07595.png
#   inflating: drive/MyDrive/test_data/test/07596.png
#   inflating: drive/MyDrive/test_data/test/07597.png
#   inflating: drive/MyDrive/test_data/test/07598.png
#   inflating: drive/MyDrive/test_data/test/07599.png
#  extracting: drive/MyDrive/test_data/test/07600.png
#   inflating: drive/MyDrive/test_data/test/07601.png
#   inflating: drive/MyDrive/test_data/test/07602.png
#  extracting: drive/MyDrive/test_data/test/07603.png
#   inflating: drive/MyDrive/test_data/test/07604.png
#  extracting: drive/MyDrive/test_data/test/07605.png
#  extracting: drive/MyDrive/test_data/test/07606.png
#   inflating: drive/MyDrive/test_data/test/07607.png
#   inflating: drive/MyDrive/test_data/test/07608.png
#   inflating: drive/MyDrive/test_data/test/07609.png
#   inflating: drive/MyDrive/test_data/test/07610.png
#   inflating: drive/MyDrive/test_data/test/07611.png
#   inflating: drive/MyDrive/test_data/test/07612.png
#   inflating: drive/MyDrive/test_data/test/07613.png
#   inflating: drive/MyDrive/test_data/test/07614.png
#   inflating: drive/MyDrive/test_data/test/07615.png
#  extracting: drive/MyDrive/test_data/test/07616.png
#   inflating: drive/MyDrive/test_data/test/07617.png
# ...
#   inflating: drive/MyDrive/test_data/test/11435.png
#   inflating: drive/MyDrive/test_data/test/11436.png
#   inflating: drive/MyDrive/test_data/test/11437.png
#  extracting: drive/MyDrive/test_data/test/11438.png
#   inflating: drive/MyDrive/test_data/test/11439.png
#   inflating: drive/MyDrive/test_data/test/11440.png
#   inflating: drive/MyDrive/test_data/test/11441.png
#   inflating: drive/MyDrive/test_data/test/11442.png
#   inflating: drive/MyDrive/test_data/test/11443.png
#   inflating: drive/MyDrive/test_data/test/11444.png
#   inflating: drive/MyDrive/test_data/test/11445.png
#   inflating: drive/MyDrive/test_data/test/11446.png
#  extracting: drive/MyDrive/test_data/test/11447.png
#   inflating: drive/MyDrive/test_data/test/11448.png
#   inflating: drive/MyDrive/test_data/test/11449.png
#  extracting: drive/MyDrive/test_data/test/11450.png
#   inflating: drive/MyDrive/test_data/test/11451.png
#   inflating: drive/MyDrive/test_data/test/11452.png
#  extracting: drive/MyDrive/test_data/test/11453.png
#   inflating: drive/MyDrive/test_data/test/11454.png
#   inflating: drive/MyDrive/test_data/test/11455.png
#   inflating: drive/MyDrive/test_data/test/11456.png
#   inflating: drive/MyDrive/test_data/test/11457.png
#   inflating: drive/MyDrive/test_data/test/11458.png
#  extracting: drive/MyDrive/test_data/test/11459.png
#  extracting: drive/MyDrive/test_data/test/11460.png
#   inflating: drive/MyDrive/test_data/test/11461.png
#   inflating: drive/MyDrive/test_data/test/11462.png
#  extracting: drive/MyDrive/test_data/test/11463.png
#   inflating: drive/MyDrive/test_data/test/11464.png
#   inflating: drive/MyDrive/test_data/test/11465.png
#   inflating: drive/MyDrive/test_data/test/11466.png
#  extracting: drive/MyDrive/test_data/test/11467.png
#   inflating: drive/MyDrive/test_data/test/11468.png
#   inflating: drive/MyDrive/test_data/test/11469.png
#  extracting: drive/MyDrive/test_data/test/11470.png
#   inflating: drive/MyDrive/test_data/test/11471.png
#   inflating: drive/MyDrive/test_data/test/11472.png
#  extracting: drive/MyDrive/test_data/test/11473.png
#   inflating: drive/MyDrive/test_data/test/11474.png
#   inflating: drive/MyDrive/test_data/test/11475.png
#  extracting: drive/MyDrive/test_data/test/11476.png
#  extracting: drive/MyDrive/test_data/test/11477.png
#   inflating: drive/MyDrive/test_data/test/11478.png
#  extracting: drive/MyDrive/test_data/test/11479.png
#   inflating: drive/MyDrive/test_data/test/11480.png
#   inflating: drive/MyDrive/test_data/test/11481.png
#   inflating: drive/MyDrive/test_data/test/11482.png
#   inflating: drive/MyDrive/test_data/test/11483.png
#  extracting: drive/MyDrive/test_data/test/11484.png
#   inflating: drive/MyDrive/test_data/test/11485.png
#   inflating: drive/MyDrive/test_data/test/11486.png
#   inflating: drive/MyDrive/test_data/test/11487.png
#  extracting: drive/MyDrive/test_data/test/11488.png
#  extracting: drive/MyDrive/test_data/test/11489.png
#   inflating: drive/MyDrive/test_data/test/11490.png
#   inflating: drive/MyDrive/test_data/test/11491.png
#   inflating: drive/MyDrive/test_data/test/11492.png
#   inflating: drive/MyDrive/test_data/test/11493.png
#   inflating: drive/MyDrive/test_data/test/11494.png
#   inflating: drive/MyDrive/test_data/test/11495.png
#  extracting: drive/MyDrive/test_data/test/11496.png
#   inflating: drive/MyDrive/test_data/test/11497.png
#   inflating: drive/MyDrive/test_data/test/11498.png
#   inflating: drive/MyDrive/test_data/test/11499.png
#   inflating: drive/MyDrive/test_data/test/11500.png
#  extracting: drive/MyDrive/test_data/test/11501.png
#   inflating: drive/MyDrive/test_data/test/11502.png
#  extracting: drive/MyDrive/test_data/test/11503.png
#   inflating: drive/MyDrive/test_data/test/11504.png
#  extracting: drive/MyDrive/test_data/test/11505.png
#  extracting: drive/MyDrive/test_data/test/11506.png
#   inflating: drive/MyDrive/test_data/test/11507.png
#  extracting: drive/MyDrive/test_data/test/11508.png
#   inflating: drive/MyDrive/test_data/test/11509.png
#   inflating: drive/MyDrive/test_data/test/11510.png
#  extracting: drive/MyDrive/test_data/test/11511.png
#   inflating: drive/MyDrive/test_data/test/11512.png
#   inflating: drive/MyDrive/test_data/test/11513.png
#   inflating: drive/MyDrive/test_data/test/11514.png
#   inflating: drive/MyDrive/test_data/test/11515.png
#   inflating: drive/MyDrive/test_data/test/11516.png
#  extracting: drive/MyDrive/test_data/test/11517.png
#  extracting: drive/MyDrive/test_data/test/11518.png
#  extracting: drive/MyDrive/test_data/test/11519.png
#   inflating: drive/MyDrive/test_data/test/11520.png
#   inflating: drive/MyDrive/test_data/test/11521.png
#   inflating: drive/MyDrive/test_data/test/11522.png
#   inflating: drive/MyDrive/test_data/test/11523.png
#  extracting: drive/MyDrive/test_data/test/11524.png
#   inflating: drive/MyDrive/test_data/test/11525.png
#   inflating: drive/MyDrive/test_data/test/11526.png
#   inflating: drive/MyDrive/test_data/test/11527.png
#  extracting: drive/MyDrive/test_data/test/11528.png
#   inflating: drive/MyDrive/test_data/test/11529.png
#   inflating: drive/MyDrive/test_data/test/11530.png
#   inflating: drive/MyDrive/test_data/test/11531.png
#   inflating: drive/MyDrive/test_data/test/11532.png
#  extracting: drive/MyDrive/test_data/test/11533.png
#  extracting: drive/MyDrive/test_data/test/11534.png
#   inflating: drive/MyDrive/test_data/test/11535.png
#   inflating: drive/MyDrive/test_data/test/11536.png
#   inflating: drive/MyDrive/test_data/test/11537.png
#  extracting: drive/MyDrive/test_data/test/11538.png
#  extracting: drive/MyDrive/test_data/test/11539.png
#  extracting: drive/MyDrive/test_data/test/11540.png
#   inflating: drive/MyDrive/test_data/test/11541.png
#   inflating: drive/MyDrive/test_data/test/11542.png
#  extracting: drive/MyDrive/test_data/test/11543.png
#   inflating: drive/MyDrive/test_data/test/11544.png
#   inflating: drive/MyDrive/test_data/test/11545.png
#  extracting: drive/MyDrive/test_data/test/11546.png
#  extracting: drive/MyDrive/test_data/test/11547.png
#   inflating: drive/MyDrive/test_data/test/11548.png
#  extracting: drive/MyDrive/test_data/test/11549.png
#  extracting: drive/MyDrive/test_data/test/11550.png
#  extracting: drive/MyDrive/test_data/test/11551.png
#   inflating: drive/MyDrive/test_data/test/11552.png
#   inflating: drive/MyDrive/test_data/test/11553.png
#   inflating: drive/MyDrive/test_data/test/11554.png
#   inflating: drive/MyDrive/test_data/test/11555.png
#   inflating: drive/MyDrive/test_data/test/11556.png
#  extracting: drive/MyDrive/test_data/test/11557.png
#   inflating: drive/MyDrive/test_data/test/11558.png
#  extracting: drive/MyDrive/test_data/test/11559.png
#   inflating: drive/MyDrive/test_data/test/11560.png
#   inflating: drive/MyDrive/test_data/test/11561.png
#  extracting: drive/MyDrive/test_data/test/11562.png
#   inflating: drive/MyDrive/test_data/test/11563.png
#  extracting: drive/MyDrive/test_data/test/11564.png
#   inflating: drive/MyDrive/test_data/test/11565.png
#  extracting: drive/MyDrive/test_data/test/11566.png
#   inflating: drive/MyDrive/test_data/test/11567.png
#   inflating: drive/MyDrive/test_data/test/11568.png
#   inflating: drive/MyDrive/test_data/test/11569.png
#   inflating: drive/MyDrive/test_data/test/11570.png
#   inflating: drive/MyDrive/test_data/test/11571.png
#   inflating: drive/MyDrive/test_data/test/11572.png
#   inflating: drive/MyDrive/test_data/test/11573.png
#  extracting: drive/MyDrive/test_data/test/11574.png
#   inflating: drive/MyDrive/test_data/test/11575.png
#   inflating: drive/MyDrive/test_data/test/11576.png
#   inflating: drive/MyDrive/test_data/test/11577.png
#   inflating: drive/MyDrive/test_data/test/11578.png
#   inflating: drive/MyDrive/test_data/test/11579.png
#   inflating: drive/MyDrive/test_data/test/11580.png
#  extracting: drive/MyDrive/test_data/test/11581.png
#   inflating: drive/MyDrive/test_data/test/11582.png
#   inflating: drive/MyDrive/test_data/test/11583.png
#  extracting: drive/MyDrive/test_data/test/11584.png
#   inflating: drive/MyDrive/test_data/test/11585.png
#  extracting: drive/MyDrive/test_data/test/11586.png
#   inflating: drive/MyDrive/test_data/test/11587.png
#  extracting: drive/MyDrive/test_data/test/11588.png
#   inflating: drive/MyDrive/test_data/test/11589.png
#   inflating: drive/MyDrive/test_data/test/11590.png
#   inflating: drive/MyDrive/test_data/test/11591.png
#   inflating: drive/MyDrive/test_data/test/11592.png
#   inflating: drive/MyDrive/test_data/test/11593.png
#   inflating: drive/MyDrive/test_data/test/11594.png
#   inflating: drive/MyDrive/test_data/test/11595.png
#   inflating: drive/MyDrive/test_data/test/11596.png
#  extracting: drive/MyDrive/test_data/test/11597.png
#   inflating: drive/MyDrive/test_data/test/11598.png
#   inflating: drive/MyDrive/test_data/test/11599.png
#   inflating: drive/MyDrive/test_data/test/11600.png
#   inflating: drive/MyDrive/test_data/test/11601.png
#   inflating: drive/MyDrive/test_data/test/11602.png
#   inflating: drive/MyDrive/test_data/test/11603.png
#  extracting: drive/MyDrive/test_data/test/11604.png
#   inflating: drive/MyDrive/test_data/test/11605.png
#   inflating: drive/MyDrive/test_data/test/11606.png
#   inflating: drive/MyDrive/test_data/test/11607.png
#   inflating: drive/MyDrive/test_data/test/11608.png
#   inflating: drive/MyDrive/test_data/test/11609.png
#  extracting: drive/MyDrive/test_data/test/11610.png
#   inflating: drive/MyDrive/test_data/test/11611.png
#   inflating: drive/MyDrive/test_data/test/11612.png
#  extracting: drive/MyDrive/test_data/test/11613.png
#  extracting: drive/MyDrive/test_data/test/11614.png
#   inflating: drive/MyDrive/test_data/test/11615.png
#   inflating: drive/MyDrive/test_data/test/11616.png
#   inflating: drive/MyDrive/test_data/test/11617.png
#   inflating: drive/MyDrive/test_data/test/11618.png
#   inflating: drive/MyDrive/test_data/test/11619.png
#   inflating: drive/MyDrive/test_data/test/11620.png
#   inflating: drive/MyDrive/test_data/test/11621.png
#   inflating: drive/MyDrive/test_data/test/11622.png
#   inflating: drive/MyDrive/test_data/test/11623.png
#   inflating: drive/MyDrive/test_data/test/11624.png
#   inflating: drive/MyDrive/test_data/test/11625.png
#   inflating: drive/MyDrive/test_data/test/11626.png
#   inflating: drive/MyDrive/test_data/test/11627.png
#   inflating: drive/MyDrive/test_data/test/11628.png
#  extracting: drive/MyDrive/test_data/test/11629.png
#  extracting: drive/MyDrive/test_data/test/11630.png
#   inflating: drive/MyDrive/test_data/test/11631.png
#   inflating: drive/MyDrive/test_data/test/11632.png
#   inflating: drive/MyDrive/test_data/test/11633.png
#   inflating: drive/MyDrive/test_data/test/11634.png
#   inflating: drive/MyDrive/test_data/test/11635.png
#   inflating: drive/MyDrive/test_data/test/11636.png
#   inflating: drive/MyDrive/test_data/test/11637.png
#  extracting: drive/MyDrive/test_data/test/11638.png
#   inflating: drive/MyDrive/test_data/test/11639.png
#   inflating: drive/MyDrive/test_data/test/11640.png
#   inflating: drive/MyDrive/test_data/test/11641.png
#   inflating: drive/MyDrive/test_data/test/11642.png
#   inflating: drive/MyDrive/test_data/test/11643.png
#  extracting: drive/MyDrive/test_data/test/11644.png
#   inflating: drive/MyDrive/test_data/test/11645.png
#   inflating: drive/MyDrive/test_data/test/11646.png
#   inflating: drive/MyDrive/test_data/test/11647.png
#   inflating: drive/MyDrive/test_data/test/11648.png
#   inflating: drive/MyDrive/test_data/test/11649.png
#   inflating: drive/MyDrive/test_data/test/11650.png
#  extracting: drive/MyDrive/test_data/test/11651.png
#   inflating: drive/MyDrive/test_data/test/11652.png
#   inflating: drive/MyDrive/test_data/test/11653.png
#  extracting: drive/MyDrive/test_data/test/11654.png
#   inflating: drive/MyDrive/test_data/test/11655.png
#   inflating: drive/MyDrive/test_data/test/11656.png
#   inflating: drive/MyDrive/test_data/test/11657.png
#   inflating: drive/MyDrive/test_data/test/11658.png
#  extracting: drive/MyDrive/test_data/test/11659.png
#   inflating: drive/MyDrive/test_data/test/11660.png
#  extracting: drive/MyDrive/test_data/test/11661.png
#   inflating: drive/MyDrive/test_data/test/11662.png
#   inflating: drive/MyDrive/test_data/test/11663.png
#   inflating: drive/MyDrive/test_data/test/11664.png
#  extracting: drive/MyDrive/test_data/test/11665.png
#  extracting: drive/MyDrive/test_data/test/11666.png
#   inflating: drive/MyDrive/test_data/test/11667.png
#  extracting: drive/MyDrive/test_data/test/11668.png
#  extracting: drive/MyDrive/test_data/test/11669.png
#   inflating: drive/MyDrive/test_data/test/11670.png
#   inflating: drive/MyDrive/test_data/test/11671.png
#   inflating: drive/MyDrive/test_data/test/11672.png
#   inflating: drive/MyDrive/test_data/test/11673.png
#   inflating: drive/MyDrive/test_data/test/11674.png
#   inflating: drive/MyDrive/test_data/test/11675.png
#   inflating: drive/MyDrive/test_data/test/11676.png
#   inflating: drive/MyDrive/test_data/test/11677.png
#   inflating: drive/MyDrive/test_data/test/11678.png
#   inflating: drive/MyDrive/test_data/test/11679.png
#   inflating: drive/MyDrive/test_data/test/11680.png
#   inflating: drive/MyDrive/test_data/test/11681.png
#  extracting: drive/MyDrive/test_data/test/11682.png
#  extracting: drive/MyDrive/test_data/test/11683.png
#   inflating: drive/MyDrive/test_data/test/11684.png
#   inflating: drive/MyDrive/test_data/test/11685.png
#   inflating: drive/MyDrive/test_data/test/11686.png
#   inflating: drive/MyDrive/test_data/test/11687.png
#   inflating: drive/MyDrive/test_data/test/11688.png
#   inflating: drive/MyDrive/test_data/test/11689.png
#   inflating: drive/MyDrive/test_data/test/11690.png
#   inflating: drive/MyDrive/test_data/test/11691.png
#  extracting: drive/MyDrive/test_data/test/11692.png
#   inflating: drive/MyDrive/test_data/test/11693.png
#   inflating: drive/MyDrive/test_data/test/11694.png
#  extracting: drive/MyDrive/test_data/test/11695.png
#  extracting: drive/MyDrive/test_data/test/11696.png
#  extracting: drive/MyDrive/test_data/test/11697.png
#   inflating: drive/MyDrive/test_data/test/11698.png
#   inflating: drive/MyDrive/test_data/test/11699.png
#  extracting: drive/MyDrive/test_data/test/11700.png
#   inflating: drive/MyDrive/test_data/test/11701.png
#  extracting: drive/MyDrive/test_data/test/11702.png
#   inflating: drive/MyDrive/test_data/test/11703.png
#   inflating: drive/MyDrive/test_data/test/11704.png
#   inflating: drive/MyDrive/test_data/test/11705.png
#   inflating: drive/MyDrive/test_data/test/11706.png
#   inflating: drive/MyDrive/test_data/test/11707.png
#   inflating: drive/MyDrive/test_data/test/11708.png
#   inflating: drive/MyDrive/test_data/test/11709.png
#  extracting: drive/MyDrive/test_data/test/11710.png
#  extracting: drive/MyDrive/test_data/test/11711.png
#   inflating: drive/MyDrive/test_data/test/11712.png
#   inflating: drive/MyDrive/test_data/test/11713.png
#   inflating: drive/MyDrive/test_data/test/11714.png
#   inflating: drive/MyDrive/test_data/test/11715.png
#   inflating: drive/MyDrive/test_data/test/11716.png
#   inflating: drive/MyDrive/test_data/test/11717.png
#   inflating: drive/MyDrive/test_data/test/11718.png
#   inflating: drive/MyDrive/test_data/test/11719.png
#   inflating: drive/MyDrive/test_data/test/11720.png
#   inflating: drive/MyDrive/test_data/test/11721.png
#   inflating: drive/MyDrive/test_data/test/11722.png
#   inflating: drive/MyDrive/test_data/test/11723.png
#  extracting: drive/MyDrive/test_data/test/11724.png
#   inflating: drive/MyDrive/test_data/test/11725.png
#   inflating: drive/MyDrive/test_data/test/11726.png
#   inflating: drive/MyDrive/test_data/test/11727.png
#   inflating: drive/MyDrive/test_data/test/11728.png
#  extracting: drive/MyDrive/test_data/test/11729.png
#   inflating: drive/MyDrive/test_data/test/11730.png

# %% [markdown]
# This should have created the folders train_val_data and test_data in your google drive.

# %%
root = "./drive/MyDrive/" # where are these folders located?

# %% [markdown]
# Now we have to create Datasets from these folders.
#
# For the train_val folder the images are sorted into their correct class folder.
# For the test folder we don't know the correct classes.
#
# We will use ImageFolder Datasets from  [PyTorch](https://pytorch.org/vision/stable/generated/torchvision.datasets.ImageFolder.html#torchvision.datasets.ImageFolder)
#
# Each Image Folder uses [transforms](https://pytorch.org/vision/stable/transforms.html) to augment the image and create a tensor out of it.
#
# Some initial transforms are given. You are allowed (and probably should) add more transformations or modify the existing ones

# %%
test_transform = transforms.Compose([
        transforms.CenterCrop(120), # makes that every image has size 120*120 # you can choose different resolutions
        # you can add more augmentations here
        transforms.ToTensor(), # creates a tensor out of Image
    ])

train_val_transform = transforms.Compose([
        transforms.CenterCrop(120), # should be the same resolution as the test_transform
        transforms.ToTensor(),
    ])

# %% [markdown]
# Now we use these transformations to create our dataset

# %%
train_val_folder = root + "train_val_data/"
train_val_dataset = datasets.ImageFolder(train_val_folder, transform=train_val_transform)

train_val_length = len(train_val_dataset)
print(f"The trainval dataset contains {train_val_length} labeled images") # should be 3000


test_folder = root + "test_data/"
test_dataset = datasets.ImageFolder(test_folder, transform=test_transform)

print(f"The test dataset contains {len(test_dataset)} unlabeled images") # should be 8730

# %% [markdown]
# Let's look at the first element of our dataset

# %%
first_elem = train_val_dataset.__getitem__(0)
print(f"An element of a dataset contains {len(first_elem)} fields. (should be 2). The first field is an image, the second value is its corresponding label \n")

# the first index should be a tensor representation of an image
print("tensor of first image", first_elem[0], "\n")

print("image should be of shape 3,size,size: ", first_elem[0].shape)

# convert tensor back to a PIL image and visualize it with display()
display(transforms.ToPILImage()(first_elem[0]))
# Each folder is a class
classes = train_val_dataset.classes
print("We have the follwing classes", classes)

# Each classname is assigned an index
class_names = train_val_dataset.class_to_idx
print("Each class gets an index value", class_names)

# the second index is the numerical value of our label taken from the folder name
print(f"For the first image we have index {first_elem[1]}")

# %% [markdown]
# Split this dataset into a training set and a validation set.
# For this you can use [random_split](https://pytorch.org/docs/stable/data.html#torch.utils.data.random_split)
#
# In this example we will use 10% of the dataset for training and 90% for validation. You should change this percentage to a reasonable value
# Remember overfitting and underfitting

# %%
train_percentage = 0.1 # how much of the dataset should be used for training --> change this value

no_train_images = int(train_val_length * train_percentage)
no_valid_images = train_val_length - no_train_images

train_dataset, valid_dataset = random_split(dataset=train_val_dataset, lengths=[no_train_images ,no_valid_images], generator=torch.Generator().manual_seed(42))

print(f"we divided the {len(train_val_dataset)} labeled images into {len(train_dataset)} training images and {len(valid_dataset)} validation images")

# %% [markdown]
# Let's Create [Dataloaders](https://pytorch.org/docs/stable/data.html)
# Dataloaders loads our data in batches and faster so out training speed increases.
#
# The important arguments of the Dataloader are `dataset, batch_size, shuffle and  num_workers`
# We are already giving the argument for dataset, you should choose fitting values for the other arguments

# %% [markdown]
# Let's create dataloaders for train and test

# %%
train_loader = DataLoader(dataset=train_dataset) # You are free to add values for other arguments
valid_loader = DataLoader(dataset=valid_dataset) # You are free to add values add values for other arguments

# %% [markdown]
# Lets visualize images from the train loader

# %%
def vis_batch(loader):
    def show(inp, label):
        fig = plt.gcf()
        plt.imshow(inp.permute(1,2,0))
        plt.title(label)
    
    for batch_inputs, labels in loader:
        grid = torchvision.utils.make_grid(batch_inputs)
        show(grid, label=[classes[int(labels[x])] for x in range(len(labels))])
        break
vis_batch(train_loader)

# %% [markdown]
# Let's create a  dummy pytorch model that takes an image and predicts a class

# %%
# Do not use this model.
model = nn.Sequential(
    nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3,padding=1),
    nn.Flatten(),
    nn.Linear(in_features=120*120*3, out_features=12) # your model has to predict 12 classes so your last layer should most likely be a linear layer with 12 out_features
)

# %% [markdown]
# You should use a different model.
# Also you should now train your model.

# %% [markdown]
# # Mein Modell
#
# ## Importiere Libaries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler
from torch.optim.lr_scheduler import _LRScheduler
import torch.utils.data as data

import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models

from sklearn import decomposition
from sklearn import manifold
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import numpy as np

import copy
from collections import namedtuple
import os
import random
import shutil
import time

# %% [markdown]
# Set the seed for reproductability.

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# Setze Directories zu Datensätzen

# %%
train_dir = root + "train_val_data/"
test_dir= root + "test_data/"

# %% [markdown]
# Normalisiere die Daten:

# %%
train_data = datasets.ImageFolder(root = train_dir, 
                                  transform = transforms.ToTensor())

# Initialise Mean and Standard deviation array
means = torch.zeros(3)
stds = torch.zeros(3)

for img, label in train_data:
    means += torch.mean(img, dim = (1,2))
    stds += torch.std(img, dim = (1,2))

means /= len(train_data)
stds /= len(train_data)
    
print(f'Calculated means: {means}')
print(f'Calculated stds: {stds}')
# Out:
# Calculated means: tensor([0.4795, 0.4722, 0.4359])
# Calculated stds: tensor([0.1675, 0.1676, 0.1834])

# %% [markdown]
# Bild Transformation and Augmentation of Train Data

# %%
pretrained_size = 224 
pretrained_means = [0.485, 0.456, 0.406] #depend on the pretrained net
pretrained_stds= [0.229, 0.224, 0.225]  #depend on the pretrained net

train_transforms = transforms.Compose([
                           transforms.Resize(pretrained_size), #makes that every image has resolution of 224*224
                           transforms.RandomRotation(5),
                           transforms.RandomHorizontalFlip(0.5),
                           transforms.RandomCrop(pretrained_size, padding = 10),
                           transforms.ToTensor(), #creates a tensor out of image
                           transforms.Normalize(mean = pretrained_means, 
                                                std = pretrained_stds)
                       ])

test_transforms = transforms.Compose([
                           transforms.Resize(pretrained_size),
                           transforms.CenterCrop(pretrained_size),
                           transforms.ToTensor(),
                           transforms.Normalize(mean = pretrained_means, 
                                                std = pretrained_stds)
                       ])

# %% [markdown]
# Load data with transforms

# %%
train_data = datasets.ImageFolder(root = train_dir, 
                                  transform = train_transforms)

test_data = datasets.ImageFolder(root = test_dir, 
                                 transform = test_transforms)

# %% [markdown]
# Create validation Split

# %%
VALID_RATIO = 0.9

n_train_examples = int(len(train_data) * VALID_RATIO)
n_valid_examples = len(train_data) - n_train_examples

train_data, valid_data = data.random_split(train_data, 
                                           [n_train_examples, n_valid_examples])

print("# of training examples", n_train_examples, "# of validation examples", n_valid_examples)
# Out:
# # of training examples 2700 # of validation examples 300

# %% [markdown]
# Overwrite the validation transforms, making sure to do a deecopy to stop this also changing the training data transforms.

# %%
valid_data = copy.deepcopy(valid_data)
valid_data.dataset.transform = test_transforms

# %%
print(f'Number of training examples: {len(train_data)}')
print(f'Number of validation examples: {len(valid_data)}')
print(f'Number of testing examples: {len(test_data)}')
# Out:
# Number of training examples: 2700
# Number of validation examples: 300
# Number of testing examples: 8730

# %% [markdown]
# Create the iterators with the largest batch size
#
# An iterator is an object that allows you to traverse through a collection of items, such as a list or a dataset, one at a time. In Python, an iterator is an object that implements two methods: `__iter__()` and `__next__()`.
#
# The `__iter__()` method returns the iterator object itself. This method is called when the for loop starts.
#
# The `__next__()` method returns the next item from the iterator. This method is called every time the for loop proceeds to the next iteration.
#
# In deep learning, iterators are often used to load and process data in small chunks, as loading the entire dataset into memory can be impractical. One common example is the DataLoader class in PyTorch library, which is used to create a iterator that loads and processes data in batches for training and evaluation.

# %%
# Get the maximum amount of GPU memory that has been allocated
max_gpu_memory = torch.cuda.max_memory_allocated()

# Calculate the maximum batch size that can fit in the GPU memory
#batch_size = max_gpu_memory // (input_size * output_size * 4) # 4 bytes per float

print("Max GPU", max_gpu_memory)
#print("Max batch size", batch_size)
# Out:
# Max GPU 0

# %%
BATCH_SIZE = 64

train_iterator = data.DataLoader(train_data, 
                                 shuffle = True, 
                                 batch_size = BATCH_SIZE)

valid_iterator = data.DataLoader(valid_data, 
                                 batch_size = BATCH_SIZE)

test_iterator = data.DataLoader(test_data, 
                                batch_size = BATCH_SIZE)

# %% [markdown]
# The following method should not be changed. It predicts the classes for each image in the test dataset and stores them in a .csv file.

# %%
def create_result_file(model, test_dataset, classes): # DO NOT CHANGE THIS METHOD
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    keys = ["ImageName", *classes]  

    prediction_dict = {key: [] for key in keys}
    names = test_dataset.imgs
    model.to(device)
    model.eval() # set model to evaluation mode. 
    for i in range(len(test_dataset)):
        input = test_dataset.__getitem__(i)
        input = input[0].to(device).unsqueeze(0) # take image tensor and add batch dimension
        with torch.no_grad(): # don't calculate gradients
            outputs = model(input).cpu().squeeze().numpy() # get prediction for input image
            prediction_dict["ImageName"].append(os.path.basename(names[i][0])) # save image name
            for class_idx, class_name in enumerate(classes): # save prediction for each class 
                prediction_dict[class_name].append(outputs[class_idx])
        
    df = pd.DataFrame.from_dict(prediction_dict) # convert list into pandas dataframe
    df.to_csv("result.csv", index=False) # save dataframe as .csv

# %% [markdown]
# After training we can execute the
# `
# create_result_file(model, test_dataset, classes) method
# `
# In this given code we skip training and use our untrained model

# %%
create_result_file(model, test_dataset, classes)

# %% [markdown]
# If you use Google colab, press the button `update/aktualisieren`
# <div>
# <img src=https://git.scc.kit.edu/vy9905/ml2images/-/raw/main/UpdateColab.jpg width="300">
# <div>
# You should see that the file result.csv was created. You can now download this file and upload it at
#
# https://kit-ml1.streamlitapp.com/
